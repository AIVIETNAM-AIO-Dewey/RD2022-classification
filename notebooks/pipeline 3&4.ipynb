# %%
# 1. Trở về gốc và dọn dẹp thư mục cũ
# %cd /content/
# !rm -rf image-preprocessing-classification

# 2. Tải source code (chỉ định chính xác nhánh develop)
# !git clone -b develop https://github.com/AIVIETNAM-AIO-Dewey/image-preprocessing-classification.git

# 3. Di chuyển vào thư mục dự án
# %cd /content/image-preprocessing-classification

# 4. Cài đặt thư viện
# !pip install -r requirements.txt

# 5. Tải data và cắt patch (sẽ mất vài phút)
# !python src/data/download_data.py
# !python src/data/process_patches.py
# Out:
# /content
# Cloning into 'image-preprocessing-classification'...
# remote: Enumerating objects: 241, done.
# remote: Counting objects: 100% (49/49), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 241 (delta 20), reused 23 (delta 16), pack-reused 192 (from 1)
# Receiving objects: 100% (241/241), 905.21 KiB | 11.91 MiB/s, done.
# Resolving deltas: 100% (100/100), done.
# /content/image-preprocessing-classification
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (2.11.0+cu128)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (0.26.0+cu128)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (2.2.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (4.13.0.92)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (11.3.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (1.6.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 8)) (3.10.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 9)) (6.0.3)
# Requirement already satisfied: albumentations in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 10)) (2.0.8)
# Requirement already satisfied: gdown in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 11)) (5.2.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (3.29.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r requirements.txt (line 1)) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r requirements.txt (line 1)) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r requirements.txt (line 1)) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r requirements.txt (line 1)) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r requirements.txt (line 1)) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r requirements.txt (line 1)) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r requirements.txt (line 1)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r requirements.txt (line 1)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r requirements.txt (line 1)) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r requirements.txt (line 1)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r requirements.txt (line 1)) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r requirements.txt (line 1)) (12.8.90)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->-r requirements.txt (line 4)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->-r requirements.txt (line 4)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->-r requirements.txt (line 4)) (2026.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r requirements.txt (line 7)) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r requirements.txt (line 7)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r requirements.txt (line 7)) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 8)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 8)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 8)) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 8)) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 8)) (26.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 8)) (3.3.2)
# Requirement already satisfied: pydantic>=2.9.2 in /usr/local/lib/python3.12/dist-packages (from albumentations->-r requirements.txt (line 10)) (2.12.3)
# Requirement already satisfied: albucore==0.0.24 in /usr/local/lib/python3.12/dist-packages (from albumentations->-r requirements.txt (line 10)) (0.0.24)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.12/dist-packages (from albumentations->-r requirements.txt (line 10)) (4.13.0.92)
# Requirement already satisfied: stringzilla>=3.10.4 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.24->albumentations->-r requirements.txt (line 10)) (4.6.2)
# Requirement already satisfied: simsimd>=5.9.2 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.24->albumentations->-r requirements.txt (line 10)) (6.5.16)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown->-r requirements.txt (line 11)) (4.13.5)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.12/dist-packages (from gdown->-r requirements.txt (line 11)) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from gdown->-r requirements.txt (line 11)) (4.67.3)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch->-r requirements.txt (line 1)) (1.5.5)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations->-r requirements.txt (line 10)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations->-r requirements.txt (line 10)) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations->-r requirements.txt (line 10)) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 4)) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown->-r requirements.txt (line 11)) (2.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->-r requirements.txt (line 1)) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown->-r requirements.txt (line 11)) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown->-r requirements.txt (line 11)) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown->-r requirements.txt (line 11)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown->-r requirements.txt (line 11)) (2026.5.20)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown->-r requirements.txt (line 11)) (1.7.1)
# Downloading dataset from Google Drive (ID: 1oMDFwlGwObPg0kmyFVGVoYEMtc8ubOWT)...
# Downloading...
# From (original): https://drive.google.com/uc?id=1oMDFwlGwObPg0kmyFVGVoYEMtc8ubOWT
# From (redirected): https://drive.google.com/uc?id=1oMDFwlGwObPg0kmyFVGVoYEMtc8ubOWT&confirm=t&uuid=5ab80b09-19fb-4ddf-b043-aa5f6003e20e
# To: /content/image-preprocessing-classification/data/raw/rdd2022_india.zip
# 100% 527M/527M [00:06<00:00, 77.4MB/s]
# Extracting dataset...
# Extraction completed successfully!
# Cleaned up the zip file.
# Found dataset at: data/raw/India/train
# Total xml annotation files: 7706
# Processing train split (5394 images)...
# 100% 5394/5394 [00:18<00:00, 292.35it/s]
# Processing val split (1156 images)...
# 100% 1156/1156 [00:05<00:00, 218.63it/s]
# Processing test split (1156 images)...
# 100% 1156/1156 [00:03<00:00, 308.76it/s]
# Patch preprocessing completed!
#
# Stats for train:
#   - D00: 1102 patches
#   - D20: 1403 patches
#   - D40: 2278 patches
#   - Normal: 7900 patches
#
# Stats for val:
#   - D00: 225 patches
#   - D20: 300 patches
#   - D40: 465 patches
#   - Normal: 1671 patches
#
# Stats for test:
#   - D00: 228 patches
#   - D20: 318 patches
#   - D40: 444 patches
#   - Normal: 1663 patches

# %%
# Mẹo: Ô này là code Python kết hợp bash để in luôn ảnh ra
# %cd /content/image-preprocessing-classification
import os
from IPython.display import Image, display

print("\n" + "="*50)
print("⚙️ 1/2. ĐANG CHẠY PIPELINE 3 (SIÊU THAM SỐ GỐC)...")
# !PYTHONPATH=. python src/data/preprocess_dataset.py --config configs/pipeline3_grayscale_bilateral.yaml
# !PYTHONPATH=. python src/training/train.py --config configs/pipeline3_grayscale_bilateral.yaml

print("\n🎯 BẮT ĐẦU ĐÁNH GIÁ (GỐC)...")
# !PYTHONPATH=. python src/evaluation/evaluate.py --config configs/pipeline3_grayscale_bilateral.yaml --model_path outputs/pipeline3_grayscale_bilateral/best_model.pth

img_path_goc = "/content/image-preprocessing-classification/outputs/pipeline3_grayscale_bilateral/confusion_matrix.png"
if os.path.exists(img_path_goc):
    print("\n📊 MA TRẬN NHẦM LẪN (GỐC):")
    display(Image(img_path_goc))
# Out:
# /content/image-preprocessing-classification
#
# ==================================================
# ⚙️ 1/2. ĐANG CHẠY PIPELINE 3 (SIÊU THAM SỐ GỐC)...
#
# --- Offline Preprocessing: pipeline3_grayscale_bilateral ---
# Reorganizing raw cropped patches: moving train/val/test to data/processed/cropped
# Reading raw cropped images from: data/processed/cropped
# Saving preprocessed images to: data/processed/grayscale_bilateral
# Processing split 'train', class 'D00' (1102 images)...
# 100% 1102/1102 [00:01<00:00, 570.57it/s]
# Processing split 'train', class 'D20' (1403 images)...
# 100% 1403/1403 [00:08<00:00, 170.03it/s]
# Processing split 'train', class 'D40' (2278 images)...
# 100% 2278/2278 [00:03<00:00, 597.15it/s]
# Processing split 'train', class 'Normal' (7900 images)...
# 100% 7900/7900 [00:15<00:00, 509.63it/s]
# Processing split 'val', class 'D00' (225 images)...
# 100% 225/225 [00:00<00:00, 550.53it/s]
# Processing split 'val', class 'D20' (300 images)...
# 100% 300/300 [00:01<00:00, 181.36it/s]
# Processing split 'val', class 'D40' (465 images)...
# 100% 465/465 [00:00<00:00, 712.00it/s]
# Processing split 'val', class 'Normal' (1671 images)...
# 100% 1671/1671 [00:03<00:00, 503.83it/s]
# Processing split 'test', class 'D00' (228 images)...
# 100% 228/228 [00:00<00:00, 435.22it/s]
# Processing split 'test', class 'D20' (318 images)...
# 100% 318/318 [00:02<00:00, 154.73it/s]
# Processing split 'test', class 'D40' (444 images)...
# 100% 444/444 [00:00<00:00, 697.55it/s]
# Processing split 'test', class 'Normal' (1663 images)...
# 100% 1663/1663 [00:03<00:00, 537.77it/s]
# Offline preprocessing completed successfully! Saved dataset to: data/processed/grayscale_bilateral
# --- Starting Experiment: pipeline3_grayscale_bilateral ---
# Using device: cuda
# [train] Loading preprocessed dataset from: data/processed/grayscale_bilateral/train
# Loaded 12683 images for split: train
# [val] Loading preprocessed dataset from: data/processed/grayscale_bilateral/val
# Loaded 2661 images for split: val
# Using CosineAnnealingLR scheduler (T_max=30, eta_min=1e-06)
# Epoch [1/30] LR: 0.001000 | Train Loss: 0.7940 | Train Acc: 67.03% | Val Loss: 0.7540 | Val Acc: 69.64%
#   => Saved new best model checkpoint (Val Acc: 69.64%)
# Epoch [2/30] LR: 0.000997 | Train Loss: 0.7092 | Train Acc: 69.39% | Val Loss: 0.6610 | Val Acc: 71.33%
#   => Saved new best model checkpoint (Val Acc: 71.33%)
# Epoch [3/30] LR: 0.000989 | Train Loss: 0.6755 | Train Acc: 71.43% | Val Loss: 0.6485 | Val Acc: 74.03%
#   => Saved new best model checkpoint (Val Acc: 74.03%)
# Epoch [4/30] LR: 0.000976 | Train Loss: 0.6506 | Train Acc: 73.32% | Val Loss: 1.6248 | Val Acc: 71.63%
# Epoch [5/30] LR: 0.000957 | Train Loss: 0.5922 | Train Acc: 76.07% | Val Loss: 0.5950 | Val Acc: 76.36%
#   => Saved new best model checkpoint (Val Acc: 76.36%)
# Epoch [6/30] LR: 0.000933 | Train Loss: 0.5439 | Train Acc: 78.13% | Val Loss: 0.5349 | Val Acc: 78.47%
#   => Saved new best model checkpoint (Val Acc: 78.47%)
# Epoch [7/30] LR: 0.000905 | Train Loss: 0.5036 | Train Acc: 80.00% | Val Loss: 0.5693 | Val Acc: 78.54%
#   => Saved new best model checkpoint (Val Acc: 78.54%)
# Epoch [8/30] LR: 0.000872 | Train Loss: 0.4688 | Train Acc: 81.34% | Val Loss: 0.4902 | Val Acc: 80.61%
#   => Saved new best model checkpoint (Val Acc: 80.61%)
# Epoch [9/30] LR: 0.000835 | Train Loss: 0.4228 | Train Acc: 83.45% | Val Loss: 0.5346 | Val Acc: 78.24%
# Epoch [10/30] LR: 0.000794 | Train Loss: 0.3826 | Train Acc: 85.44% | Val Loss: 0.4526 | Val Acc: 82.71%
#   => Saved new best model checkpoint (Val Acc: 82.71%)
# Epoch [11/30] LR: 0.000750 | Train Loss: 0.3550 | Train Acc: 86.61% | Val Loss: 0.4011 | Val Acc: 84.97%
#   => Saved new best model checkpoint (Val Acc: 84.97%)
# Epoch [12/30] LR: 0.000704 | Train Loss: 0.3341 | Train Acc: 87.35% | Val Loss: 0.3781 | Val Acc: 85.04%
#   => Saved new best model checkpoint (Val Acc: 85.04%)
# Epoch [13/30] LR: 0.000655 | Train Loss: 0.3152 | Train Acc: 88.56% | Val Loss: 0.3225 | Val Acc: 88.05%
#   => Saved new best model checkpoint (Val Acc: 88.05%)
# Epoch [14/30] LR: 0.000604 | Train Loss: 0.2879 | Train Acc: 89.48% | Val Loss: 0.4859 | Val Acc: 82.94%
# Epoch [15/30] LR: 0.000553 | Train Loss: 0.2602 | Train Acc: 90.45% | Val Loss: 0.3500 | Val Acc: 86.55%
# Epoch [16/30] LR: 0.000501 | Train Loss: 0.2267 | Train Acc: 91.78% | Val Loss: 0.3582 | Val Acc: 86.96%
# Epoch [17/30] LR: 0.000448 | Train Loss: 0.1959 | Train Acc: 92.79% | Val Loss: 0.3789 | Val Acc: 87.26%
# Epoch [18/30] LR: 0.000397 | Train Loss: 0.1737 | Train Acc: 93.68% | Val Loss: 0.3405 | Val Acc: 87.75%
#
# [Early Stopping] Val accuracy did not improve for 5 epochs. Stopping.
# --- Training Completed. Best Val Acc: 88.05%. Results saved to outputs/pipeline3_grayscale_bilateral ---
#
# 🎯 BẮT ĐẦU ĐÁNH GIÁ (GỐC)...
# --- Evaluating model for: pipeline3_grayscale_bilateral ---
# [test] Loading preprocessed dataset from: data/processed/grayscale_bilateral/test
# Loaded 2653 images for split: test
# Model weights loaded successfully.
#
# --- Test Set Classification Report ---
#               precision    recall  f1-score   support
#
#          D00       0.69      0.62      0.65       228
#          D20       0.74      0.67      0.70       318
#          D40       0.81      0.78      0.80       444
#       Normal       0.93      0.97      0.95      1663
#
#     accuracy                           0.87      2653
#    macro avg       0.79      0.76      0.77      2653
# weighted avg       0.87      0.87      0.87      2653
#
# Overall Accuracy: 87.11%
#
# Evaluation completed. Metrics and confusion matrix saved to outputs/pipeline3_grayscale_bilateral
#
# 📊 MA TRẬN NHẦM LẪN (GỐC):

# %%
# %%writefile configs/pipeline3_tuned.yaml
# exp_name: "pipeline3_tuned"
# data_dir: "data/processed"
# output_dir: "outputs/pipeline3_tuned"
# model_name: "resnet18"
# pretrained: false
# num_classes: 4
# epochs: 30
# batch_size: 64
# learning_rate: 0.001
# weight_decay: 0.0001
# device: "cuda"
# use_scheduler: true
# scheduler_T_max: 30
# scheduler_eta_min: 0.000001
# early_stopping_patience: 5
# image_size: 224
# mean: [0.485, 0.456, 0.406]
# std: [0.229, 0.224, 0.225]
# preprocessing_mode: "grayscale_bilateral"
# preprocessing_params:
#   grayscale_bilateral:
#     d: 5                       # ĐÃ ĐỔI: Giảm vùng lấy mẫu (gốc: 9)
#     sigma_color: 20            # ĐÃ ĐỔI: Giảm làm mịn màu để giữ vết nứt (gốc: 75)
#     sigma_space: 20            # ĐÃ ĐỔI: Giảm làm mịn không gian (gốc: 75)
# Out:
# Writing configs/pipeline3_tuned.yaml

# %%
# %cd /content/image-preprocessing-classification
import os
from IPython.display import Image, display

print("\n" + "="*50)
print("🚀 2/2. ĐANG CHẠY PIPELINE 3 (CHỈ CHỈNH SỬA THAM SỐ GRAYSCALE & BILATERAL)...")
# !PYTHONPATH=. python src/data/preprocess_dataset.py --config configs/pipeline3_tuned.yaml
# !PYTHONPATH=. python src/training/train.py --config configs/pipeline3_tuned.yaml

print("\n🎯 BẮT ĐẦU ĐÁNH GIÁ (THAM SỐ ĐÃ CHỈNH SỬA)...")
# !PYTHONPATH=. python src/evaluation/evaluate.py --config configs/pipeline3_tuned.yaml --model_path outputs/pipeline3_tuned/best_model.pth

img_path_tuned = "/content/image-preprocessing-classification/outputs/pipeline3_tuned/confusion_matrix.png"
if os.path.exists(img_path_tuned):
    print("\n📊 MA TRẬN NHẦM LẪN (THAM SỐ GRAYSCALE & BILATERAL ĐÃ CHỈNH SỬA):")
    display(Image(img_path_tuned))
else:
    print(f"❌ Không tìm thấy ảnh. Vui lòng kiểm tra lại log train ở trên xem có lỗi không.")
# Out:
# /content/image-preprocessing-classification
#
# ==================================================
# 🚀 2/2. ĐANG CHẠY PIPELINE 3 (CHỈ CHỈNH SỬA THAM SỐ GRAYSCALE & BILATERAL)...
#
# --- Offline Preprocessing: pipeline3_tuned ---
# Reorganizing raw cropped patches: moving train/val/test to data/processed/cropped
# Reading raw cropped images from: data/processed/cropped
# Saving preprocessed images to: data/processed/grayscale_bilateral
# Processing split 'train', class 'D00' (1102 images)...
# 100% 1102/1102 [00:00<00:00, 1324.65it/s]
# Processing split 'train', class 'D20' (1403 images)...
# 100% 1403/1403 [00:02<00:00, 601.06it/s]
# Processing split 'train', class 'D40' (2278 images)...
# 100% 2278/2278 [00:01<00:00, 1386.26it/s]
# Processing split 'train', class 'Normal' (7900 images)...
# 100% 7900/7900 [00:07<00:00, 1110.96it/s]
# Processing split 'val', class 'D00' (225 images)...
# 100% 225/225 [00:00<00:00, 1312.49it/s]
# Processing split 'val', class 'D20' (300 images)...
# 100% 300/300 [00:00<00:00, 605.94it/s]
# Processing split 'val', class 'D40' (465 images)...
# 100% 465/465 [00:00<00:00, 1618.60it/s]
# Processing split 'val', class 'Normal' (1671 images)...
# 100% 1671/1671 [00:01<00:00, 1295.65it/s]
# Processing split 'test', class 'D00' (228 images)...
# 100% 228/228 [00:00<00:00, 1396.05it/s]
# Processing split 'test', class 'D20' (318 images)...
# 100% 318/318 [00:00<00:00, 628.43it/s]
# Processing split 'test', class 'D40' (444 images)...
# 100% 444/444 [00:00<00:00, 1479.11it/s]
# Processing split 'test', class 'Normal' (1663 images)...
# 100% 1663/1663 [00:01<00:00, 1295.03it/s]
# Offline preprocessing completed successfully! Saved dataset to: data/processed/grayscale_bilateral
# --- Starting Experiment: pipeline3_tuned ---
# Using device: cuda
# [train] Loading preprocessed dataset from: data/processed/grayscale_bilateral/train
# Loaded 12683 images for split: train
# [val] Loading preprocessed dataset from: data/processed/grayscale_bilateral/val
# Loaded 2661 images for split: val
# Using CosineAnnealingLR scheduler (T_max=30, eta_min=1e-06)
# Epoch [1/30] LR: 0.001000 | Train Loss: 0.7635 | Train Acc: 67.37% | Val Loss: 1.0018 | Val Acc: 62.65%
#   => Saved new best model checkpoint (Val Acc: 62.65%)
# Epoch [2/30] LR: 0.000997 | Train Loss: 0.7100 | Train Acc: 68.29% | Val Loss: 0.7153 | Val Acc: 66.85%
#   => Saved new best model checkpoint (Val Acc: 66.85%)
# Epoch [3/30] LR: 0.000989 | Train Loss: 0.7010 | Train Acc: 68.51% | Val Loss: 0.8510 | Val Acc: 70.95%
#   => Saved new best model checkpoint (Val Acc: 70.95%)
# Epoch [4/30] LR: 0.000976 | Train Loss: 0.6672 | Train Acc: 71.16% | Val Loss: 0.9559 | Val Acc: 71.85%
#   => Saved new best model checkpoint (Val Acc: 71.85%)
# Epoch [5/30] LR: 0.000957 | Train Loss: 0.6334 | Train Acc: 73.85% | Val Loss: 0.8035 | Val Acc: 71.89%
#   => Saved new best model checkpoint (Val Acc: 71.89%)
# Epoch [6/30] LR: 0.000933 | Train Loss: 0.6091 | Train Acc: 74.69% | Val Loss: 0.7318 | Val Acc: 74.41%
#   => Saved new best model checkpoint (Val Acc: 74.41%)
# Epoch [7/30] LR: 0.000905 | Train Loss: 0.5395 | Train Acc: 78.13% | Val Loss: 0.4940 | Val Acc: 80.42%
#   => Saved new best model checkpoint (Val Acc: 80.42%)
# Epoch [8/30] LR: 0.000872 | Train Loss: 0.4769 | Train Acc: 80.96% | Val Loss: 0.5956 | Val Acc: 74.93%
# Epoch [9/30] LR: 0.000835 | Train Loss: 0.4453 | Train Acc: 82.13% | Val Loss: 0.4775 | Val Acc: 80.68%
#   => Saved new best model checkpoint (Val Acc: 80.68%)
# Epoch [10/30] LR: 0.000794 | Train Loss: 0.4061 | Train Acc: 84.10% | Val Loss: 0.4338 | Val Acc: 82.15%
#   => Saved new best model checkpoint (Val Acc: 82.15%)
# Epoch [11/30] LR: 0.000750 | Train Loss: 0.3765 | Train Acc: 85.47% | Val Loss: 0.4003 | Val Acc: 85.27%
#   => Saved new best model checkpoint (Val Acc: 85.27%)
# Epoch [12/30] LR: 0.000704 | Train Loss: 0.3527 | Train Acc: 86.69% | Val Loss: 0.4950 | Val Acc: 80.61%
# Epoch [13/30] LR: 0.000655 | Train Loss: 0.3335 | Train Acc: 87.50% | Val Loss: 0.4970 | Val Acc: 82.90%
# Epoch [14/30] LR: 0.000604 | Train Loss: 0.2907 | Train Acc: 89.14% | Val Loss: 0.3332 | Val Acc: 87.67%
#   => Saved new best model checkpoint (Val Acc: 87.67%)
# Epoch [15/30] LR: 0.000553 | Train Loss: 0.2608 | Train Acc: 90.57% | Val Loss: 0.9256 | Val Acc: 77.38%
# Epoch [16/30] LR: 0.000501 | Train Loss: 0.2329 | Train Acc: 91.26% | Val Loss: 1.0115 | Val Acc: 80.42%
# Epoch [17/30] LR: 0.000448 | Train Loss: 0.1945 | Train Acc: 92.87% | Val Loss: 0.3379 | Val Acc: 88.80%
#   => Saved new best model checkpoint (Val Acc: 88.80%)
# Epoch [18/30] LR: 0.000397 | Train Loss: 0.1528 | Train Acc: 94.47% | Val Loss: 0.4004 | Val Acc: 86.70%
# Epoch [19/30] LR: 0.000346 | Train Loss: 0.0964 | Train Acc: 96.78% | Val Loss: 0.3855 | Val Acc: 87.71%
# Epoch [20/30] LR: 0.000297 | Train Loss: 0.0695 | Train Acc: 97.56% | Val Loss: 0.4025 | Val Acc: 88.88%
#   => Saved new best model checkpoint (Val Acc: 88.88%)
# Epoch [21/30] LR: 0.000251 | Train Loss: 0.0343 | Train Acc: 98.98% | Val Loss: 0.4318 | Val Acc: 89.29%
#   => Saved new best model checkpoint (Val Acc: 89.29%)
# Epoch [22/30] LR: 0.000207 | Train Loss: 0.0191 | Train Acc: 99.51% | Val Loss: 0.4499 | Val Acc: 88.28%
# Epoch [23/30] LR: 0.000166 | Train Loss: 0.0132 | Train Acc: 99.68% | Val Loss: 0.4379 | Val Acc: 89.03%
# Epoch [24/30] LR: 0.000129 | Train Loss: 0.0078 | Train Acc: 99.87% | Val Loss: 0.4233 | Val Acc: 89.33%
#   => Saved new best model checkpoint (Val Acc: 89.33%)
# Epoch [25/30] LR: 0.000096 | Train Loss: 0.0035 | Train Acc: 99.98% | Val Loss: 0.4289 | Val Acc: 89.63%
#   => Saved new best model checkpoint (Val Acc: 89.63%)
# Epoch [26/30] LR: 0.000068 | Train Loss: 0.0030 | Train Acc: 99.98% | Val Loss: 0.4342 | Val Acc: 89.78%
#   => Saved new best model checkpoint (Val Acc: 89.78%)
# Epoch [27/30] LR: 0.000044 | Train Loss: 0.0025 | Train Acc: 99.99% | Val Loss: 0.4384 | Val Acc: 89.74%
# Epoch [28/30] LR: 0.000025 | Train Loss: 0.0017 | Train Acc: 100.00% | Val Loss: 0.4376 | Val Acc: 89.67%
# Epoch [29/30] LR: 0.000012 | Train Loss: 0.0019 | Train Acc: 99.98% | Val Loss: 0.4414 | Val Acc: 89.63%
# Epoch [30/30] LR: 0.000004 | Train Loss: 0.0020 | Train Acc: 99.99% | Val Loss: 0.4379 | Val Acc: 89.63%
# --- Training Completed. Best Val Acc: 89.78%. Results saved to outputs/pipeline3_tuned ---
#
# 🎯 BẮT ĐẦU ĐÁNH GIÁ (THAM SỐ ĐÃ CHỈNH SỬA)...
# --- Evaluating model for: pipeline3_tuned ---
# [test] Loading preprocessed dataset from: data/processed/grayscale_bilateral/test
# Loaded 2653 images for split: test
# Model weights loaded successfully.
#
# --- Test Set Classification Report ---
#               precision    recall  f1-score   support
#
#          D00       0.70      0.75      0.72       228
#          D20       0.78      0.75      0.76       318
#          D40       0.80      0.85      0.82       444
#       Normal       0.96      0.94      0.95      1663
#
#     accuracy                           0.89      2653
#    macro avg       0.81      0.82      0.81      2653
# weighted avg       0.89      0.89      0.89      2653
#
# Overall Accuracy: 88.62%
#
# Evaluation completed. Metrics and confusion matrix saved to outputs/pipeline3_tuned
#
# 📊 MA TRẬN NHẦM LẪN (THAM SỐ GRAYSCALE & BILATERAL ĐÃ CHỈNH SỬA):

# %% [markdown]
# Pipeline 4

# %%
# Đảm bảo đứng đúng thư mục dự án
# %cd /content/image-preprocessing-classification
import os
from IPython.display import Image, display

print("\n" + "="*50)
print("⚙️ 1/2. ĐANG CHẠY PIPELINE 4 (GỐC - KẾT HỢP 3 KỸ THUẬT)...")
# !PYTHONPATH=. python src/data/preprocess_dataset.py --config configs/pipeline4_combined.yaml
# !PYTHONPATH=. python src/training/train.py --config configs/pipeline4_combined.yaml

print("\n🎯 BẮT ĐẦU ĐÁNH GIÁ (GỐC)...")
# !PYTHONPATH=. python src/evaluation/evaluate.py --config configs/pipeline4_combined.yaml --model_path outputs/pipeline4_combined/best_model.pth

img_path_goc = "/content/image-preprocessing-classification/outputs/pipeline4_combined/confusion_matrix.png"
if os.path.exists(img_path_goc):
    print("\n📊 MA TRẬN NHẦM LẪN (PIPELINE 4 GỐC):")
    display(Image(img_path_goc))
# Out:
# /content/image-preprocessing-classification
#
# ==================================================
# ⚙️ 1/2. ĐANG CHẠY PIPELINE 4 (GỐC - KẾT HỢP 3 KỸ THUẬT)...
#
# --- Offline Preprocessing: pipeline4_combined ---
# Reading raw cropped images from: data/processed/cropped
# Saving preprocessed images to: data/processed/combined
# Processing split 'train', class 'D00' (1102 images)...
# 100% 1102/1102 [00:03<00:00, 355.23it/s]
# Processing split 'train', class 'D20' (1403 images)...
# 100% 1403/1403 [00:11<00:00, 125.39it/s]
# Processing split 'train', class 'D40' (2278 images)...
# 100% 2278/2278 [00:05<00:00, 424.30it/s]
# Processing split 'train', class 'Normal' (7900 images)...
# 100% 7900/7900 [00:22<00:00, 349.12it/s]
# Processing split 'val', class 'D00' (225 images)...
# 100% 225/225 [00:00<00:00, 322.69it/s]
# Processing split 'val', class 'D20' (300 images)...
# 100% 300/300 [00:02<00:00, 126.66it/s]
# Processing split 'val', class 'D40' (465 images)...
# 100% 465/465 [00:01<00:00, 453.38it/s]
# Processing split 'val', class 'Normal' (1671 images)...
# 100% 1671/1671 [00:04<00:00, 353.69it/s]
# Processing split 'test', class 'D00' (228 images)...
# 100% 228/228 [00:00<00:00, 380.84it/s]
# Processing split 'test', class 'D20' (318 images)...
# 100% 318/318 [00:02<00:00, 110.91it/s]
# Processing split 'test', class 'D40' (444 images)...
# 100% 444/444 [00:01<00:00, 360.75it/s]
# Processing split 'test', class 'Normal' (1663 images)...
# 100% 1663/1663 [00:04<00:00, 353.99it/s]
# Offline preprocessing completed successfully! Saved dataset to: data/processed/combined
# --- Starting Experiment: pipeline4_combined ---
# Using device: cuda
# [train] Loading preprocessed dataset from: data/processed/combined/train
# Loaded 12683 images for split: train
# [val] Loading preprocessed dataset from: data/processed/combined/val
# Loaded 2661 images for split: val
# Using CosineAnnealingLR scheduler (T_max=30, eta_min=1e-06)
# Epoch [1/30] LR: 0.001000 | Train Loss: 0.3575 | Train Acc: 85.91% | Val Loss: 0.3276 | Val Acc: 88.01%
#   => Saved new best model checkpoint (Val Acc: 88.01%)
# Epoch [2/30] LR: 0.000997 | Train Loss: 0.3020 | Train Acc: 87.90% | Val Loss: 0.2788 | Val Acc: 90.00%
#   => Saved new best model checkpoint (Val Acc: 90.00%)
# Epoch [3/30] LR: 0.000989 | Train Loss: 0.2763 | Train Acc: 89.10% | Val Loss: 0.3148 | Val Acc: 87.79%
# Epoch [4/30] LR: 0.000976 | Train Loss: 0.2582 | Train Acc: 90.04% | Val Loss: 0.2815 | Val Acc: 89.67%
# Epoch [5/30] LR: 0.000957 | Train Loss: 0.2555 | Train Acc: 90.15% | Val Loss: 1.4043 | Val Acc: 65.88%
# Epoch [6/30] LR: 0.000933 | Train Loss: 0.2507 | Train Acc: 90.40% | Val Loss: 0.2813 | Val Acc: 90.15%
#   => Saved new best model checkpoint (Val Acc: 90.15%)
# Epoch [7/30] LR: 0.000905 | Train Loss: 0.2315 | Train Acc: 91.19% | Val Loss: 0.2863 | Val Acc: 89.67%
# Epoch [8/30] LR: 0.000872 | Train Loss: 0.2323 | Train Acc: 91.08% | Val Loss: 0.2507 | Val Acc: 90.53%
#   => Saved new best model checkpoint (Val Acc: 90.53%)
# Epoch [9/30] LR: 0.000835 | Train Loss: 0.2212 | Train Acc: 91.89% | Val Loss: 0.2956 | Val Acc: 87.94%
# Epoch [10/30] LR: 0.000794 | Train Loss: 0.2220 | Train Acc: 91.67% | Val Loss: 0.2768 | Val Acc: 89.59%
# Epoch [11/30] LR: 0.000750 | Train Loss: 0.2277 | Train Acc: 91.37% | Val Loss: 0.2256 | Val Acc: 91.32%
#   => Saved new best model checkpoint (Val Acc: 91.32%)
# Epoch [12/30] LR: 0.000704 | Train Loss: 0.2094 | Train Acc: 91.95% | Val Loss: 0.2295 | Val Acc: 91.02%
# Epoch [13/30] LR: 0.000655 | Train Loss: 0.2027 | Train Acc: 92.66% | Val Loss: 0.2083 | Val Acc: 92.26%
#   => Saved new best model checkpoint (Val Acc: 92.26%)
# Epoch [14/30] LR: 0.000604 | Train Loss: 0.1973 | Train Acc: 92.49% | Val Loss: 0.4062 | Val Acc: 86.58%
# Epoch [15/30] LR: 0.000553 | Train Loss: 0.1934 | Train Acc: 92.57% | Val Loss: 0.2483 | Val Acc: 90.98%
# Epoch [16/30] LR: 0.000501 | Train Loss: 0.1950 | Train Acc: 92.71% | Val Loss: 0.1997 | Val Acc: 92.60%
#   => Saved new best model checkpoint (Val Acc: 92.60%)
# Epoch [17/30] LR: 0.000448 | Train Loss: 0.1827 | Train Acc: 93.01% | Val Loss: 0.2096 | Val Acc: 92.15%
# Epoch [18/30] LR: 0.000397 | Train Loss: 0.1750 | Train Acc: 93.50% | Val Loss: 0.2061 | Val Acc: 91.96%
# Epoch [19/30] LR: 0.000346 | Train Loss: 0.1668 | Train Acc: 93.68% | Val Loss: 0.1977 | Val Acc: 92.41%
# Epoch [20/30] LR: 0.000297 | Train Loss: 0.1556 | Train Acc: 94.17% | Val Loss: 0.2242 | Val Acc: 92.07%
# Epoch [21/30] LR: 0.000251 | Train Loss: 0.1447 | Train Acc: 94.64% | Val Loss: 0.2166 | Val Acc: 92.03%
#
# [Early Stopping] Val accuracy did not improve for 5 epochs. Stopping.
# --- Training Completed. Best Val Acc: 92.60%. Results saved to outputs/pipeline4_combined ---
#
# 🎯 BẮT ĐẦU ĐÁNH GIÁ (GỐC)...
# --- Evaluating model for: pipeline4_combined ---
# [test] Loading preprocessed dataset from: data/processed/combined/test
# Loaded 2653 images for split: test
# Model weights loaded successfully.
#
# --- Test Set Classification Report ---
#               precision    recall  f1-score   support
#
#          D00       0.75      0.76      0.75       228
#          D20       0.82      0.73      0.77       318
#          D40       0.81      0.85      0.83       444
#       Normal       0.99      1.00      1.00      1663
#
#     accuracy                           0.92      2653
#    macro avg       0.84      0.83      0.84      2653
# weighted avg       0.92      0.92      0.92      2653
#
# Overall Accuracy: 92.12%
#
# Evaluation completed. Metrics and confusion matrix saved to outputs/pipeline4_combined
#
# 📊 MA TRẬN NHẦM LẪN (PIPELINE 4 GỐC):

# %%
# %%writefile configs/pipeline4_tuned.yaml
# exp_name: "pipeline4_tuned"
# data_dir: "data/processed"
# output_dir: "outputs/pipeline4_tuned"
# model_name: "resnet18"
# pretrained: false
# num_classes: 4
# epochs: 30
# batch_size: 64
# learning_rate: 0.001
# weight_decay: 0.0001
# device: "cuda"
# use_scheduler: true
# scheduler_T_max: 30
# scheduler_eta_min: 0.000001
# early_stopping_patience: 5
# image_size: 224
# mean: [0.485, 0.456, 0.406]
# std: [0.229, 0.224, 0.225]
# preprocessing_mode: "combined"
# preprocessing_params:
#   clahe:
#     clip_limit: 2.0
#     tile_grid_size: [8, 8]
#   letterbox:
#     border_mode: "constant"
#     fill_value: [0, 0, 0]
#   grayscale_bilateral:
#     d: 5                       # ĐÃ ĐỔI: Giảm vùng lấy mẫu (gốc: 9)
#     sigma_color: 20            # ĐÃ ĐỔI: Giảm làm mịn màu để giữ vết nứt (gốc: 75)
#     sigma_space: 20            # ĐÃ ĐỔI: Giảm làm mịn không gian (gốc: 75)
# Out:
# Writing configs/pipeline4_tuned.yaml

# %%
# %cd /content/image-preprocessing-classification
import os
from IPython.display import Image, display

print("\n" + "="*50)
print("🚀 2/2. ĐANG CHẠY PIPELINE 4 (CHỈ CHỈNH SỬA THAM SỐ GRAYSCALE & BILATERAL)...")
# !PYTHONPATH=. python src/data/preprocess_dataset.py --config configs/pipeline4_tuned.yaml
# !PYTHONPATH=. python src/training/train.py --config configs/pipeline4_tuned.yaml

print("\n🎯 BẮT ĐẦU ĐÁNH GIÁ (THAM SỐ ĐÃ CHỈNH SỬA)...")
# !PYTHONPATH=. python src/evaluation/evaluate.py --config configs/pipeline4_tuned.yaml --model_path outputs/pipeline4_tuned/best_model.pth

img_path_tuned = "/content/image-preprocessing-classification/outputs/pipeline4_tuned/confusion_matrix.png"
if os.path.exists(img_path_tuned):
    print("\n📊 MA TRẬN NHẦM LẪN (PIPELINE 4 - THAM SỐ ĐÃ CHỈNH SỬA):")
    display(Image(img_path_tuned))
else:
    print(f"❌ Không tìm thấy ảnh. Vui lòng kiểm tra lại log train ở trên xem có lỗi không.")
# Out:
# /content/image-preprocessing-classification
#
# ==================================================
# 🚀 2/2. ĐANG CHẠY PIPELINE 4 (CHỈ CHỈNH SỬA THAM SỐ GRAYSCALE & BILATERAL)...
#
# --- Offline Preprocessing: pipeline4_tuned ---
# Reading raw cropped images from: data/processed/cropped
# Saving preprocessed images to: data/processed/combined
# Processing split 'train', class 'D00' (1102 images)...
# 100% 1102/1102 [00:03<00:00, 286.17it/s]
# Processing split 'train', class 'D20' (1403 images)...
# 100% 1403/1403 [00:05<00:00, 247.42it/s]
# Processing split 'train', class 'D40' (2278 images)...
# 100% 2278/2278 [00:03<00:00, 659.96it/s]
# Processing split 'train', class 'Normal' (7900 images)...
# 100% 7900/7900 [00:14<00:00, 561.98it/s]
# Processing split 'val', class 'D00' (225 images)...
# 100% 225/225 [00:00<00:00, 502.00it/s]
# Processing split 'val', class 'D20' (300 images)...
# 100% 300/300 [00:01<00:00, 232.72it/s]
# Processing split 'val', class 'D40' (465 images)...
# 100% 465/465 [00:00<00:00, 748.28it/s]
# Processing split 'val', class 'Normal' (1671 images)...
# 100% 1671/1671 [00:02<00:00, 614.36it/s]
# Processing split 'test', class 'D00' (228 images)...
# 100% 228/228 [00:00<00:00, 639.37it/s]
# Processing split 'test', class 'D20' (318 images)...
# 100% 318/318 [00:01<00:00, 239.02it/s]
# Processing split 'test', class 'D40' (444 images)...
# 100% 444/444 [00:00<00:00, 699.23it/s]
# Processing split 'test', class 'Normal' (1663 images)...
# 100% 1663/1663 [00:02<00:00, 604.35it/s]
# Offline preprocessing completed successfully! Saved dataset to: data/processed/combined
# --- Starting Experiment: pipeline4_tuned ---
# Using device: cuda
# [train] Loading preprocessed dataset from: data/processed/combined/train
# Loaded 12683 images for split: train
# [val] Loading preprocessed dataset from: data/processed/combined/val
# Loaded 2661 images for split: val
# Using CosineAnnealingLR scheduler (T_max=30, eta_min=1e-06)
# Epoch [1/30] LR: 0.001000 | Train Loss: 0.3370 | Train Acc: 87.23% | Val Loss: 0.2522 | Val Acc: 91.06%
#   => Saved new best model checkpoint (Val Acc: 91.06%)
# Epoch [2/30] LR: 0.000997 | Train Loss: 0.2353 | Train Acc: 91.01% | Val Loss: 0.3749 | Val Acc: 87.60%
# Epoch [3/30] LR: 0.000989 | Train Loss: 0.2240 | Train Acc: 91.71% | Val Loss: 0.2796 | Val Acc: 88.54%
# Epoch [4/30] LR: 0.000976 | Train Loss: 0.2175 | Train Acc: 91.73% | Val Loss: 0.2623 | Val Acc: 90.30%
# Epoch [5/30] LR: 0.000957 | Train Loss: 0.2064 | Train Acc: 92.13% | Val Loss: 0.2084 | Val Acc: 93.27%
#   => Saved new best model checkpoint (Val Acc: 93.27%)
# Epoch [6/30] LR: 0.000933 | Train Loss: 0.1954 | Train Acc: 92.67% | Val Loss: 0.1928 | Val Acc: 93.16%
# Epoch [7/30] LR: 0.000905 | Train Loss: 0.1977 | Train Acc: 92.65% | Val Loss: 0.2119 | Val Acc: 92.60%
# Epoch [8/30] LR: 0.000872 | Train Loss: 0.1938 | Train Acc: 92.79% | Val Loss: 0.2510 | Val Acc: 91.39%
# Epoch [9/30] LR: 0.000835 | Train Loss: 0.1896 | Train Acc: 92.94% | Val Loss: 0.2471 | Val Acc: 92.15%
# Epoch [10/30] LR: 0.000794 | Train Loss: 0.1836 | Train Acc: 93.33% | Val Loss: 0.2586 | Val Acc: 91.28%
#
# [Early Stopping] Val accuracy did not improve for 5 epochs. Stopping.
# --- Training Completed. Best Val Acc: 93.27%. Results saved to outputs/pipeline4_tuned ---
#
# 🎯 BẮT ĐẦU ĐÁNH GIÁ (THAM SỐ ĐÃ CHỈNH SỬA)...
# --- Evaluating model for: pipeline4_tuned ---
# [test] Loading preprocessed dataset from: data/processed/combined/test
# Loaded 2653 images for split: test
# Model weights loaded successfully.
#
# --- Test Set Classification Report ---
#               precision    recall  f1-score   support
#
#          D00       0.78      0.68      0.73       228
#          D20       0.79      0.81      0.80       318
#          D40       0.83      0.85      0.84       444
#       Normal       0.99      1.00      1.00      1663
#
#     accuracy                           0.92      2653
#    macro avg       0.85      0.84      0.84      2653
# weighted avg       0.92      0.92      0.92      2653
#
# Overall Accuracy: 92.50%
#
# Evaluation completed. Metrics and confusion matrix saved to outputs/pipeline4_tuned
#
# 📊 MA TRẬN NHẦM LẪN (PIPELINE 4 - THAM SỐ ĐÃ CHỈNH SỬA):

# %%
from google.colab import files
import os

# Nén kết quả pipeline 3 và pipeline 4 đã chỉnh tham số vào 1 file zip
# !zip -r outputs_tuned_p3_p4.zip outputs/pipeline3_tuned/ outputs/pipeline4_tuned/

# Tải về máy
print("📦 Đang tải file kết quả về máy...")
files.download('/content/image-preprocessing-classification/outputs_tuned_p3_p4.zip')
print("✅ Tải xong! Kiểm tra thư mục Downloads trên máy tính của bạn nhé!")
# Out:
#   adding: outputs/pipeline3_tuned/ (stored 0%)
#   adding: outputs/pipeline3_tuned/confusion_matrix.png (deflated 21%)
#   adding: outputs/pipeline3_tuned/history.json (deflated 66%)
#   adding: outputs/pipeline3_tuned/test_evaluation.json (deflated 71%)
#   adding: outputs/pipeline3_tuned/best_model.pth (deflated 6%)
#   adding: outputs/pipeline4_tuned/ (stored 0%)
#   adding: outputs/pipeline4_tuned/confusion_matrix.png (deflated 21%)
#   adding: outputs/pipeline4_tuned/history.json (deflated 63%)
#   adding: outputs/pipeline4_tuned/test_evaluation.json (deflated 70%)
#   adding: outputs/pipeline4_tuned/best_model.pth (deflated 7%)
# 📦 Đang tải file kết quả về máy...
# ✅ Tải xong! Kiểm tra thư mục Downloads trên máy tính của bạn nhé!
